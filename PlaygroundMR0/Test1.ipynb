# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,100, 100)

plt.figure()
plt.plot(x)
plt.title("plot of array x")

np.savetxt("./results/arrayX3.txt", x)
plt.savefig("./results/arrayX3_figure.png")
