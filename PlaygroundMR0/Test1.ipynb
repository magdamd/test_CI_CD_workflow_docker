# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,200, 100)

plt.figure()
plt.plot(x)
plt.title("plot of array x")

np.savetxt("./results_LastPush/arrayX.txt", x)
plt.savefig("./results_LastPush/arrayX_figure.png")
